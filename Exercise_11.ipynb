# %% [markdown]
# <a href="https://colab.research.google.com/github/ImSumitJadhav/Pandas-Exercise/blob/main/Exercise_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Investor - Flow of Funds - US

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/datasets/investor-flow-of-funds-us/master/data/weekly.csv).

# %%
url="https://raw.githubusercontent.com/datasets/investor-flow-of-funds-us/master/data/weekly.csv"

# %% [markdown]
# ### Step 3. Assign it to a variable called

# %%
df1=pd.read_csv(url,delimiter=",")

# %%
df1.head()
# Out:
#          Date  Total Equity  Domestic Equity  World Equity  Hybrid  \
# 0  2012-12-05         -7426            -6060         -1367     -74
# 1  2012-12-12         -8783            -7520         -1263     123
# 2  2012-12-19         -5496            -5470           -26     -73
# 3  2012-12-26         -4451            -4076          -375     550
# 4  2013-01-02        -11156            -9622         -1533    -158
#
#    Total Bond  Taxable Bond  Municipal Bond  Total
# 0        5317          4210            1107  -2183
# 1        1818          1598             219  -6842
# 2         103          3472           -3369  -5466
# 3        2610          3333            -722  -1291
# 4        2383          2103             280  -8931

# %% [markdown]
# ### Step 4.  What is the frequency of the dataset?

# %%
df1.mean()
# Out:
# <ipython-input-17-00fb6bfec183>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1.mean()
# Total Equity       -161.727273
# Domestic Equity   -1815.931818
# World Equity       1654.227273
# Hybrid              684.227273
# Total Bond         2452.613636
# Taxable Bond       1931.977273
# Municipal Bond      520.613636
# Total              2975.045455
# dtype: float64

# %% [markdown]
# ### Step 5. Set the column Date as the index.

# %%
df1=df1.set_index("Date")

# %%
df1.head()
# Out:
#          Date  Total Equity  Domestic Equity  World Equity  Hybrid  \
# 0  2012-12-05         -7426            -6060         -1367     -74
# 1  2012-12-12         -8783            -7520         -1263     123
# 2  2012-12-19         -5496            -5470           -26     -73
# 3  2012-12-26         -4451            -4076          -375     550
# 4  2013-01-02        -11156            -9622         -1533    -158
#
#    Total Bond  Taxable Bond  Municipal Bond  Total
# 0        5317          4210            1107  -2183
# 1        1818          1598             219  -6842
# 2         103          3472           -3369  -5466
# 3        2610          3333            -722  -1291
# 4        2383          2103             280  -8931

# %% [markdown]
# ### Step 6. What is the type of the index?

# %%
type(df1.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %% [markdown]
# ### Step 7. Set the index to a DatetimeIndex type

# %%
df1.index=pd.to_datetime(df1.index)

# %%
type(df1.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %% [markdown]
# ### Step 8.  Change the frequency to monthly, sum the values and assign it to monthly.

# %%
mon=df1.resample("M").sum()
mon
# Out:
#             Total Equity  Domestic Equity  World Equity  Hybrid  Total Bond  \
# Date
# 2012-12-31        -26156           -23126         -3031     526        9848
# 2013-01-31          3661            -1627          5288    2730       12149
# 2013-02-28             0                0             0       0           0
# 2013-03-31             0                0             0       0           0
# 2013-04-30             0                0             0       0           0
# 2013-05-31             0                0             0       0           0
# 2013-06-30             0                0             0       0           0
# 2013-07-31             0                0             0       0           0
# 2013-08-31             0                0             0       0           0
# 2013-09-30             0                0             0       0           0
# 2013-10-31             0                0             0       0           0
# ...

# %% [markdown]
# ### Step 9. You will notice that it filled the dataFrame with months that don't have any data with NaN. Let's drop these rows.

# %%
mon.dropna(inplace=True)

# %% [markdown]
# ### Step 10. Good, now we have the monthly data. Now change the frequency to year.

# %%
year=mon.resample("AS-JAN").sum()
year
# Out:
#             Total Equity  Domestic Equity  World Equity  Hybrid  Total Bond  \
# Date
# 2012-01-01        -26156           -23126         -3031     526        9848
# 2013-01-01          3661            -1627          5288    2730       12149
# 2014-01-01           330           -44689         45021   19570       59890
# 2015-01-01         15049           -10459         25508    7280       26028
#
#             Taxable Bond  Municipal Bond  Total
# Date
# 2012-01-01         12613           -2765 -15782
# 2013-01-01          9414            2735  18540
# 2014-01-01         44994           14896  79787
# 2015-01-01         17986            8041  48357
